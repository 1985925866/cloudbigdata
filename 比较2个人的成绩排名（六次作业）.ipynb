# %%
from datascience import *
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
data1=Table.read_table('20211105-utf-8.csv')
data2=Table.read_table('20211106-utf-8.csv')
data3=Table.read_table('20211107-utf-8.csv')
data4=Table.read_table('20211108-utf-8.csv')
data5=Table.read_table('20211109-1-utf-8.csv')
data6=Table.read_table('20211109-utf-8.csv')
data7=Table.read_table('20211110-utf-8.csv')
def extract_rank(data,name):
    temp=data.where('姓名',are.equal_to(name1)).column(11).item(0)
    return temp
name1='周靖珊'
rank1=extract_rank(data1,name1)
rank2=extract_rank(data2,name1)
rank3=extract_rank(data3,name1)
rank4=extract_rank(data4,name1)
rank5=extract_rank(data5,name1)
rank6=extract_rank(data6,name1)
rank7=extract_rank(data7,name1)
rank_array=make_array(rank1,rank2,rank3,rank4,rank5,rank6,rank7)


def extract_rank(data,name):
    temp1=data.where('姓名',are.equal_to(name2)).column(11).item(0)
    return temp1
name2='黄思哲'
rank11=extract_rank(data1,name2)
rank22=extract_rank(data2,name2)
rank33=extract_rank(data3,name2)
rank44=extract_rank(data4,name2)
rank55=extract_rank(data5,name2)
rank66=extract_rank(data6,name2)
rank77=extract_rank(data7,name2)
rank_arrays=make_array(rank11,rank22,rank33,rank44,rank55,rank66,rank77)
results=Table().with_columns('序号',make_array(1,2,3,4,5,6,7),'name1',rank_array)
s=results.with_columns('name2',rank_arrays)
L1=list(s.column(1))
L2=list(s.column(2))
x = range(0,7)
y_1 = L1
y_2 = L2
plt.plot(x, y_1,label=name1, color='red', linestyle=':', marker='.', markersize=5)
plt.plot(x, y_2,label=name2, color='black',linestyle='--', marker='.', markersize=5)
plt.xlabel('历次考试')
plt.ylabel('年级 RANK')
plt.axis([0,10,650,150])
plt.legend(loc='upper right')
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.grid()
plt.show()
